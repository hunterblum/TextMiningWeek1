# %% [markdown]
# # ADS 509 Module 1: APIs and Web Scraping
#
# This notebook has two parts. In the first part, you will scrape lyrics from AZLyrics.com. In the second part, you'll run code that verifies the completeness of your data pull.
#
# For this assignment you have chosen two musical artists who have at least 20 songs with lyrics on AZLyrics.com. We start with pulling some information and analyzing them.

# %% [markdown]
# ## General Assignment Instructions
#
# These instructions are included in every assignment, to remind you of the coding standards for the class. Feel free to delete this cell after reading it.
#
# One sign of mature code is conforming to a style guide. We recommend the [Google Python Style Guide](https://google.github.io/styleguide/pyguide.html). If you use a different style guide, please include a cell with a link.
#
# Your code should be relatively easy-to-read, sensibly commented, and clean. Writing code is a messy process, so please be sure to edit your final submission. Remove any cells that are not needed or parts of cells that contain unnecessary code. Remove inessential `import` statements and make sure that all such statements are moved into the designated cell.
#
# Make use of non-code cells for written commentary. These cells should be grammatical and clearly written. In some of these cells you will have questions to answer. The questions will be marked by a "Q:" and will have a corresponding "A:" spot for you. *Make sure to answer every question marked with a `Q:` for full credit.*

# %% [markdown]
# # Importing Libraries

# %%
import os
import datetime
import re

# for the lyrics scrape section
import requests
import time
from bs4 import BeautifulSoup
from collections import defaultdict, Counter
import random

# %% [markdown]
# ---
#
# # Lyrics Scrape
#
# This section asks you to pull data from the Twitter API and scrape www.AZLyrics.com. In the notebooks where you do that work you are asked to store the data in specific ways.

# %%
artists = {'beatles':"https://www.azlyrics.com/b/beatles.html",
           'ledzeppelin':"https://www.azlyrics.com/l/ledzeppelin.html"} 
# we'll use this dictionary to hold both the artist name and the link on AZlyrics

# %% [markdown]
# ## A Note on Rate Limiting
#
# The lyrics site, www.azlyrics.com, does not have an explicit maximum on number of requests in any one time, but in our testing it appears that too many requests in too short a time will cause the site to stop returning lyrics pages. (Entertainingly, the page that gets returned seems to only have the song title to [a Tom Jones song](https://www.azlyrics.com/lyrics/tomjones/itsnotunusual.html).)
#
# Whenever you call `requests.get` to retrieve a page, put a `time.sleep(5 + 10*random.random())` on the next line. This will help you not to get blocked. If you _do_ get blocked, which you can identify if the returned pages are not correct, just request a lyrics page through your browser. You'll be asked to perform a CAPTCHA and then your requests should start working again.
#
# ## Part 1: Finding Links to Songs Lyrics
#
# That general artist page has a list of all songs for that artist with links to the individual song pages.
#
# Q: Take a look at the `robots.txt` page on www.azlyrics.com. (You can read more about these pages [here](https://developers.google.com/search/docs/advanced/robots/intro).) Is the scraping we are about to do allowed or disallowed by this page? How do you know?
#
# A:
#
# Based on the robots.txt file for the site, all user agents (*) are not allowed to scrape from paths containing /lyricsdb/ or /song/. Since none of our paths contain those, we are allowed to scrape the data from the site.

# %%
# Let's set up a dictionary of lists to hold our links
lyrics_pages = defaultdict(list)
base_url = 'https://www.azlyrics.com'
url_list = []

for artist, artist_page in artists.items() :
    # request the page and sleep
    r = requests.get(artist_page)
    time.sleep(5 + 10*random.random())
    soup = BeautifulSoup(r.text, 'html.parser')

    # now extract the links to lyrics pages from this page
    # store the links `lyrics_pages` where the key is the artist and the
    # value is a list of links. 


    for link in soup.find_all('a'):
        # get the links
        temp_href = str(link.get('href'))
        temp_url = base_url + temp_href
        url_list.append(temp_url)
    
        # only keep lyric links
        substring = artist + '/'
        url_filtered = [i for i in url_list if substring in i]
        url_filtered

        # save
        lyrics_pages[artist] = url_filtered

# %% [markdown]
# Let's make sure we have enough lyrics pages to scrape.

# %%
for artist, lp in lyrics_pages.items() :
    assert(len(set(lp)) > 20)

# %%
# Let's see how long it's going to take to pull these lyrics 
# if we're waiting `5 + 10*random.random()` seconds 
for artist, links in lyrics_pages.items() : 
    print(f"For {artist} we have {len(links)}.")
    print(f"The full pull will take for this artist will take {round(len(links)*10/3600,2)} hours.")
# Out:
# For beatles we have 427.
# The full pull will take for this artist will take 1.19 hours.
# For ledzeppelin we have 87.
# The full pull will take for this artist will take 0.24 hours.

# %%
lyrics_pages
# Out:
# defaultdict(list,
#             {'beatles': ['https://www.azlyrics.com/lyrics/beatles/isawherstandingthere.html',
#               'https://www.azlyrics.com/lyrics/beatles/misery.html',
#               'https://www.azlyrics.com/lyrics/beatles/annagotohim.html',
#               'https://www.azlyrics.com/lyrics/beatles/chains.html',
#               'https://www.azlyrics.com/lyrics/beatles/boys.html',
#               'https://www.azlyrics.com/lyrics/beatles/askmewhy.html',
#               'https://www.azlyrics.com/lyrics/beatles/pleasepleaseme.html',
#               'https://www.azlyrics.com/lyrics/beatles/lovemedo.html',
#               'https://www.azlyrics.com/lyrics/beatles/psiloveyou.html',
#               'https://www.azlyrics.com/lyrics/beatles/babyitsyou.html',
#               'https://www.azlyrics.com/lyrics/beatles/doyouwanttoknowasecret.html',
#               'https://www.azlyrics.com/lyrics/beatles/atasteofhoney.html',
#               'https://www.azlyrics.com/lyrics/beatles/theresaplace.html',
#               'https://www.azlyrics.com/lyrics/beatles/twistandshout.html',
#               'https://www.azlyrics.com/lyrics/beatles/itwontbelong.html',
#               'https://www.azlyrics.com/lyrics/beatles/allivegottodo.html',
#               'https://www.azlyrics.com/lyrics/beatles/allmyloving.html',
#               'https://www.azlyrics.com/lyrics/beatles/dontbotherme.html',
#               'https://www.azlyrics.com/lyrics/beatles/littlechild.html',
#               'https://www.azlyrics.com/lyrics/beatles/tilltherewasyou.html',
#               'https://www.azlyrics.com/lyrics/beatles/pleasemisterpostman.html',
#               'https://www.azlyrics.com/lyrics/beatles/rolloverbeethoven.html',
#               'https://www.azlyrics.com/lyrics/beatles/holdmetight.html',
#               'https://www.azlyrics.com/lyrics/beatles/youreallygotaholdonme.html',
#               'https://www.azlyrics.com/lyrics/beatles/iwannabeyourman.html',
#               'https://www.azlyrics.com/lyrics/beatles/devilinherheart.html',
#               'https://www.azlyrics.com/lyrics/beatles/notasecondtime.html',
#               'https://www.azlyrics.com/lyrics/beatles/moneythatswhatiwant.html',
#               'https://www.azlyrics.com/lyrics/beatles/aharddaysnight.html',
#               'https://www.azlyrics.com/lyrics/beatles/ishouldhaveknownbetter.html',
#               'https://www.azlyrics.com/lyrics/beatles/ififell.html',
#               'https://www.azlyrics.com/lyrics/beatles/theend.html',
#               'https://www.azlyrics.com/lyrics/beatles/badtome.html',
#               'https://www.azlyrics.com/lyrics/beatles/canyoutakemeback.html',
#               'https://www.azlyrics.com/lyrics/beatles/gniknus.html',
#               'https://www.azlyrics.com/lyrics/beatles/happybirthdaydearsaturdayclub.html',
#               'https://www.azlyrics.com/lyrics/beatles/watchingrainbows.html'],
#              'ledzeppelin': ['https://www.azlyrics.com/lyrics/ledzeppelin/goodtimesbadtimes.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/babeimgonnaleaveyou.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/youshookme.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/dazedandconfused.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/yourtimeisgonnacome.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/communicationbreakdown.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/icantquityoubaby15292.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/howmanymoretimes.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/wholelottalove.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/whatisandwhatshouldneverbe.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/thelemonsong.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/thankyou.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/heartbreaker.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/livinglovingmaidshesjustawoman.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/rambleon.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/bringitonhome.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/immigrantsong.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/friends.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/celebrationday.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/sinceivebeenlovingyou.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/outonthetiles.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/gallowspole.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/tangerine.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/thatstheway.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/bronyaurstomp.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/hatsofftoroyharper.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/keytothehighwaytroubleinmind.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/blackdog.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/rockandroll.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/thebattleofevermore.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/stairwaytoheaven.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/mistymountainhop.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/foursticks.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/goingtocalifornia.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/whentheleveebreaks.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/thesongremainsthesame.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/therainsong.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/overthehillsandfaraway.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/thecrunge.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/dancingdays.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/dyermaker.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/noquarter.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/theocean.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/custardpie.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/therover.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/inmytimeofdying.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/housesoftheholy.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/trampledunderfoot.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/kashmir.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/inthelight.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/downbytheseaside.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/tenyearsgone.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/nightflight.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/thewantonsong.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/boogiewithstu.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/blackcountrywoman.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/sickagain.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/achilleslaststand.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/foryourlife.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/royalorleans.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/nobodysfaultbutmine.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/candystorerock.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/hotsonfornowhere.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/teaforone.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/intheevening.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/southboundsaurez.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/foolintherain.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/hotdog.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/carouselambra.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/allmylove.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/imgonnacrawl.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/weregonnagroove.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/poortom.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/icantquityoubaby.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/walterswalk.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/ozonebaby.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/darlene.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/wearingandtearing.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/babycomeonhome.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/travellingriversideblues.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/heyheywhatcanido.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/ifitkeepsonrainingroughmix.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/sugarmamamix.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/bringitonhomeroughmix.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/everybodymakesitthrough.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/somethinelse.html',
#               'https://www.azlyrics.com/lyrics/ledzeppelin/thegirliloveshegotlongblackwavyhair.html']})

# %% [markdown]
# ## Part 2: Pulling Lyrics
#
# Now that we have the links to our lyrics pages, let's go scrape them! Here are the steps for this part.
#
# 1. Create an empty folder in our repo called "lyrics".
# 1. Iterate over the artists in `lyrics_pages`.
# 1. Create a subfolder in lyrics with the artist's name. For instance, if the artist was Cher you'd have `lyrics/cher/` in your repo.
# 1. Iterate over the pages.
# 1. Request the page and extract the lyrics from the returned HTML file using BeautifulSoup.
# 1. Use the function below, `generate_filename_from_url`, to create a filename based on the lyrics page, then write the lyrics to a text file with that name.

# %%
# There wasn't an underscore in the replace useless characters - figured it should be added
def generate_filename_from_link(link) :
    
    if not link :
        return None
    
    # drop the http or https and the html
    name = link.replace("https","").replace("http","")
    name = link.replace(".html","")

    name = name.replace("/lyrics/","")
    
    # Replace useless chareacters with UNDERSCORE
    name = name.replace("://","_").replace(".","_").replace("/","_")
    
    # tack on .txt
    name = name + ".txt"
    
    return(name)

# %%
# Make the lyrics folder here. If you'd like to practice your programming, add functionality 
# that checks to see if the folder exists. If it does, then use shutil.rmtree to remove it and create a new one.
import shutil
if os.path.isdir("lyrics") : 
    shutil.rmtree("lyrics/")

os.mkdir("lyrics")

# %%
# I know it is against the style guide, 
# but code freezes without importing shutil in each chunk
# not sure what the issue is since I think it's standard library
import shutil

start = time.time()

total_pages = 5
for artist in lyrics_pages:
    # 1. Create the subfolder
    subfold = "lyrics/" + artist
    if os.path.isdir(subfold):
        shutil.rmtree(subfold + '/')
    os.mkdir(subfold)

    # 2. Iterate over the lyrics pages
    i = 0
    urls = lyrics_pages[artist]

    while i < total_pages:
        temp_url = urls[i]

        # 3. Request the lyrics page
        r = requests.get(temp_url)
        time.sleep(3)

        soup = BeautifulSoup(r.text, 'html.parser')

        # 4. Extract the title and lyrics
        title = soup.find_all('b')[1].get_text()
        lyrics = soup.find_all('div')[22].get_text()

        # 4b. lets go ahead and combine with the two returns
        song = title + '\n\n' + lyrics

        # 5. Write out the file
        wd = os.getcwd()
        folders = "\\lyrics\\" + artist
        filepath = wd + folders
        filename = generate_filename_from_link(temp_url)
        pathname = filepath + '\\' + filename

        text_file = open(pathname, "w")
        text_file.write(song)
        text_file.close()

        i +=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29200\2426302437.py in <module>
#      28
#      29         # 4. Extract the title and lyrics
# ---> 30         title = soup.find_all('b')[1].get_text()
#      31         lyrics = soup.find_all('div')[22].get_text()
#      32
#
# IndexError: list index out of range

# %%
print(f"Total run time was {round((time.time() - start)/3600,2)} hours.")
# Out:
# Total run time was 0.02 hours.

# %% [markdown]
# ---
#
# # Evaluation
#
# This assignment asks you to pull data from the Twitter API and scrape www.AZLyrics.com.  After you have finished the above sections , run all the cells in this notebook. Print this to PDF and submit it, per the instructions.

# %%
# Simple word extractor from Peter Norvig: https://norvig.com/spell-correct.html
def words(text): 
    return re.findall(r'\w+', text.lower())

# %% [markdown]
# ## Checking Lyrics
#
# The output from your lyrics scrape should be stored in files located in this path from the directory:
# `/lyrics/[Artist Name]/[filename from URL]`. This code summarizes the information at a high level to help the instructor evaluate your work.

# %%
artist_folders = os.listdir("lyrics/")
artist_folders = [f for f in artist_folders if os.path.isdir("lyrics/" + f)]

for artist in artist_folders : 
    artist_files = os.listdir("lyrics/" + artist)
    artist_files = [f for f in artist_files if 'txt' in f or 'csv' in f or 'tsv' in f]

    print(f"For {artist} we have {len(artist_files)} files.")

    artist_words = []

    for f_name in artist_files : 
        with open("lyrics/" + artist + "/" + f_name) as infile : 
            artist_words.extend(words(infile.read()))

            
    print(f"For {artist} we have roughly {len(artist_words)} words, {len(set(artist_words))} are unique.")
# Out:
# For beatles we have 20 files.
# For beatles we have roughly 3616 words, 384 are unique.
# For ledzeppelin we have 20 files.
# For ledzeppelin we have roughly 4666 words, 717 are unique.
